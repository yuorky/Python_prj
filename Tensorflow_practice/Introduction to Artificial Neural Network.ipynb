# %% [markdown]
# A Preception Class

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron

iris = load_iris()
X = iris.data[:,(2,3)]
y = (iris.target == 0).astype(np.int)

per_clf = Perceptron(random_state=42)
per_clf.fit(X,y)

y_pred = per_clf.predict([[2,0.5]])
# Out:
# C:\Users\y63qiu\AppData\Local\Continuum\anaconda3\envs\mlbook\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in Perceptron in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)

# %%
y_pred
# Out:
# array([1])

# %% [markdown]
# # Train a DNN with 2 hidden layers and a softmax output layer

# %%
import tensorflow as tf
import numpy as np

(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train = X_train.astype(np.float32).reshape(-1, 28*28) / 255.0
X_test = X_test.astype(np.float32).reshape(-1, 28*28) / 255.0
y_train = y_train.astype(np.int64)
y_test = y_test.astype(np.int64)
X_valid, X_train = X_train[:5000], X_train[5000:]
y_valid, y_train = y_train[:5000], y_train[5000:]

# %%
feature_cols = [tf.feature_column.numeric_column("X", shape=[28*28])]
dnn_clf = tf.estimator.DNNClassifier(hidden_units=[300,100], n_classes=10,
                                    feature_columns=feature_cols)

input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"X": X_train}, y=y_train, num_epochs=40, batch_size=50,shuffle=True)
dnn_clf.train(input_fn=input_fn)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\y63qiu\AppData\Local\Temp\tmpdl8bikln
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\y63qiu\\AppData\\Local\\Temp\\tmpdl8bikln', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %%
test_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"X": X_test}, y=y_test, shuffle=True)
eval_results = dnn_clf.evaluate(input_fn=test_input_fn)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-11-22:41:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\y63qiu\AppData\Local\Temp\tmpdl8bikln\model.ckpt-44000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-11-22:41:52
# INFO:tensorflow:Saving dict for global step 44000: accuracy = 0.9802, average_loss = 0.10345824, global_step = 44000, loss = 13.09598
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 44000: C:\Users\y63qiu\AppData\Local\Temp\tmpdl8bikln\model.ckpt-44000

# %%
eval_results
# Out:
# {'accuracy': 0.9802,
#  'average_loss': 0.10345824,
#  'loss': 13.09598,
#  'global_step': 44000}

# %%
y_pred_iter = dnn_clf.predict(input_fn=test_input_fn)

# %%
list(y_pred_iter)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\y63qiu\AppData\Local\Temp\tmpdl8bikln\model.ckpt-44000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([ -3.409957 ,  -9.449229 ,   1.9496661,   3.973871 , -11.2279005,
#           -9.756104 ,  -7.581313 ,  -7.5860353,  23.341984 ,  -2.2476614],
#         dtype=float32),
#   'probabilities': array([2.4086813e-12, 5.7405922e-15, 5.1219445e-10, 3.8773553e-09,
#          9.6937002e-16, 4.2236053e-15, 3.7169127e-14, 3.6994076e-14,
#          1.0000000e+00, 7.7011965e-12], dtype=float32),
#   'class_ids': array([8], dtype=int64),
#   'classes': array([b'8'], dtype=object)},
#  {'logits': array([-15.428224 , -16.065113 , -13.533055 ,   8.284391 , -21.502686 ,
#           39.925247 ,  -6.9753585, -16.439081 ,  12.517948 ,   1.6407945],
#         dtype=float32),
# ...

# %% [markdown]
# # Train a DNN using plain Tensorflow

# %%
n_inputs = 28*28
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

# %% [markdown]
# ## Construction phase

# %%
# represent training data and labels using placeholder

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

# %%
# function that create one layer at a time, args are # of neurons, the activiation function, and the name of the layer

def neuron_layer(X, n_neurons, name, activation=None):
    with tf.name_scope(name):
        n_inputs = int(X.get_shape()[1])
        stddev = 2 / np.sqrt(n_inputs)
        init = tf.truncated_normal((n_inputs,n_neurons),stddev=stddev)
        W = tf.Variable(init, name="Weights")
        b = tf.Variable(tf.zeros([n_neurons]), name="biases")
        z = tf.matmul(X, W) + b
        if activation == "relu":
            return tf.nn.relu(z)
        else:
            return z

# %%
# create a 2-hidden-layers NN

with tf.name_scope("dnn"):
    hidden1 = neuron_layer(X, n_hidden1, "hidden1", activation="relu")
    hidden2 = neuron_layer(hidden1, n_hidden2, "hidden2", activation="relu")
    logits = neuron_layer(hidden2,n_outputs,"outputs")  # output before going through softmax function

# %% [markdown]
# Using dense() function to create NN

# %%
with tf.name_scope("dnn"):
    hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1",activation=tf.nn.relu)
    hidden2 = tf.layers.dense(hidden1, n_hidden2, name="hidden2",activation=tf.nn.relu)
    logits = tf.layers.dense(hidden2, n_outputs, name="outputs")
    y_proba = tf.nn.softmax(logits)

# %%
# define cost function
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(
                    labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss") # average

# %%
# define an optimizer to minimize the cost function

learning_rate = 0.01

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
# final step of construction phrase: evaluate the model

with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits,y,1)
    accuracy = tf.reduce_mean(tf.cast(correct,tf.float32))

# %%
# create initializer and saver

init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %% [markdown]
# ## Execution phase

# %% [markdown]
# Load the MNIST data

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/")
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# Define the # of epoch and size of mini-batches

# %%
n_epochs = 40
batch_size = 50

# %% [markdown]
# Train the model

# %%
def shuffle_batch(X, y, batch_size):
    rnd_idx = np.random.permutation(len(X))
    n_batches = len(X) // batch_size
    for batch_idx in np.array_split(rnd_idx, n_batches):
        X_batch, y_batch = X[batch_idx], y[batch_idx]
        yield X_batch, y_batch

# %%
with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_batch = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_val = accuracy.eval(feed_dict={X: X_valid, y: y_valid})
        print(epoch, "Batch accuracy:", acc_batch, "Val accuracy:", acc_val)

    save_path = saver.save(sess, "./my_model_final.ckpt")
# Out:
# 0 Batch accuracy: 0.94 Val accuracy: 0.9024
# 1 Batch accuracy: 0.94 Val accuracy: 0.9236
# 2 Batch accuracy: 0.94 Val accuracy: 0.9336
# 3 Batch accuracy: 0.98 Val accuracy: 0.9412
# 4 Batch accuracy: 1.0 Val accuracy: 0.9454
# 5 Batch accuracy: 0.96 Val accuracy: 0.948
# 6 Batch accuracy: 0.96 Val accuracy: 0.9524
# 7 Batch accuracy: 1.0 Val accuracy: 0.9562
# 8 Batch accuracy: 0.96 Val accuracy: 0.96
# 9 Batch accuracy: 1.0 Val accuracy: 0.9628
# 10 Batch accuracy: 0.98 Val accuracy: 0.963
# 11 Batch accuracy: 1.0 Val accuracy: 0.9664
# 12 Batch accuracy: 0.98 Val accuracy: 0.9672
# 13 Batch accuracy: 1.0 Val accuracy: 0.9692
# 14 Batch accuracy: 0.96 Val accuracy: 0.9706
# 15 Batch accuracy: 1.0 Val accuracy: 0.9716
# 16 Batch accuracy: 1.0 Val accuracy: 0.9704
# 17 Batch accuracy: 0.96 Val accuracy: 0.9728
# 18 Batch accuracy: 1.0 Val accuracy: 0.9734
# 19 Batch accuracy: 1.0 Val accuracy: 0.9742
# 20 Batch accuracy: 0.92 Val accuracy: 0.9756
# ...

# %%
with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(mnist.train.num_examples//batch_size):
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={X:X_batch, y:y_batch})
        acc_train = accuracy.eval(feed_dict={X:X_batch, y:y_batch})
        acc_test = accuracy.eval(feed_dict={X: mnist.test.images,
                                           y: mnist.test.labels})
        #print(epoch, "Train accuracy:" acc_train, "Test accuracy:", acc_test)
        
    save_path = saver.save(sess,"./my_model_final.ckpt")

# %% [markdown]
# reuse the Network

# %%
with tf.Session() as sess:
    saver.restore(sess,"./my_model_final.ckpt")
    X_new_scaled = X_test[:20]
    Z = logits.eval(feed_dict={X:X_new_scaled})
    y_pred = np.argmax(Z,axis=1)
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_final.ckpt

# %%
print("Predicted classes:", y_pred)
# Out:
# Predicted classes: [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]

# %%
print("Actual classes:", y_test[:20])
# Out:
# Actual classes: [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]
