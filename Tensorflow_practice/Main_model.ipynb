# %% [markdown]
# # Data analysis of the database (Fluoro-Crossed Data Points)

# %% [markdown]
# ## Table of Contents
# [Import Data and Basic preparation](#import)
# [Data Preparation (Ignore)](#dataprepi)
# [Data Preparation (Balancing)(Ignore)](#dataprepb)
# [Training Using Scikit Learn](#sklearn)
# ..[Support Vector Machine](#svmk)
# ..[Ensemble Learning](#ensemble)
# [Training Using Xgboost](#xgboost)
# [Training Using Tensorflow](#tf)
# [Summary of All Classifiers](#sklearn_sum)
# <br>
# <br>
# This project focused on using data points in the database to construct the correlation between fluorescence and polarization signal. The main goal is to use the statistics of polarization signal to predict whether fluorescence signal of the deposit exists.
# There are four categories of data points: (naming->{f: fluorescence, c: crossed, t: Positive, f: negative})
# 1. ftct: Deposits are fluorescence positive and polarization positive. (num: 789)
# 2. ftcf: Deposits are fluorescence positive but polarization negative. (num: 20)
# 3. ffct: Deposits are fluorescence negative but polarization positive. (num: 131)
# 4. ffcf: Deposits are both negative in fluorescence and polarization signals. Since the number of deposits in this   category is too small, we use the background retina of ftct deposits as the data points for this category.

# %% [markdown]
# ## Import Data and Basic preparation
# <a id="import"></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.io import loadmat
import os

# %%
datapath = os.getcwd() + "\\data\\dbt_m.csv"
df = pd.read_csv(datapath)

# %%
list(df)
# the fluorescence variable name: FluoroSignal
# Out:
# ['RegionFolder',
#  'Subject',
#  'Species',
#  'Age',
#  'Gender',
#  'CauseOfDeath',
#  'TimeOfDeath',
#  'MedicalHistory',
#  'Diagnosis1Type',
#  'Diagnosis1Level',
#  'Is1PrimaryDiagnosis',
#  'Diagnosis2Type',
#  'Diagnosis2Level',
#  'Is2PrimaryDiagnosis',
#  'Diagnosis3Type',
#  'Diagnosis3Level',
#  'Is3PrimaryDiagnosis',
#  'Braak_stage_tau',
#  'NP_CERAD_Biel',
#  'NP_FC_Biel',
#  'NP_TC_Biel',
#  'NP_PC_Biel',
#  'NP_score',
#  'DP_CERAD_Biel',
#  'DP_score',
#  'A_beta_thal',
#  'Thal_Phase',
#  'CAA_CR',
#  'CAA_Abeta_Cb',
#  'CAA_A_beta_and_CR',
#  'ABC_score',
#  'Likelihood_of_AD',
#  'SubjectNotes',
#  'EntryOrder',
#  'MicroscopeMotors',
#  'Sample',
#  'EyeSource',
#  'EyeInitialFixative',
#  'EyeInitialFixativePercent',
#  'EyeInitialFixingTime',
#  'EyeDissectionDoneBy',
#  'EyeMountingDoneBy',
#  'EyeMountingDate_1',
#  'EyeMountingDate_2',
#  'EyeMountingDate_3',
#  'EyeMountingDate_4',
#  'EyeStain',
#  'EyeMounting',
#  'EyeQuarterPositions',
#  'EyeNotes',
#  'Region',
#  'ImagingDoneBy',
#  'XCoordinate',
#  'YCoordinate',
#  'RadialDistanceFromFovea',
#  'ImageMagnification',
#  'BWPixelSizeMicrons',
#  'RGBPixelSizeMicrons',
#  'RegionNotes',
#  'FluoroSignal',
#  'CrossedSignal',
#  'RegionStatus',
#  'RejectedReason',
#  'DepositCountWeight',
#  'UniqueDepositID',
#  'FirstInSubject',
#  'FirstInSample',
#  'FirstInQuarter',
#  'Old_QuarterMountingDoneBy',
#  'Old_QuarterMountingDate',
#  'Old_QuarterStain',
#  'Old_QuarterType',
#  'Old_QuarterNotes',
#  'Old_LocationNotes',
#  'Old_FluoroSignature',
#  'Old_CrossedSignature',
#  'Old_VisualSignature',
#  'Old_IsDeposit',
#  'Old_ImageRejected',
#  'Old_RejectedReason',
#  'Old_RejectedBy',
#  'Old_DAMMSubjectIdx',
#  'Old_DAMMEyeIdx',
#  'Old_DAMMQuarterIdx',
#  'Old_DAMMLocationIdx',
#  'Old_YDriveQuarter',
#  'Old_YDriveLocation',
#  'Reg_Method',
#  'Reg_Smoothing',
#  'Reg_MaxShift',
#  'Reg_DoublePeak',
#  'Reg_WeightByPeakIntensity',
#  'Reg_XShifts_ 1',
#  'Reg_XShifts_ 2',
#  'Reg_XShifts_ 3',
#  'Reg_XShifts_ 4',
#  'Reg_XShifts_ 5',
#  'Reg_XShifts_ 6',
#  'Reg_XShifts_ 7',
#  'Reg_XShifts_ 8',
#  'Reg_XShifts_ 9',
#  'Reg_XShifts_10',
#  'Reg_XShifts_11',
#  'Reg_XShifts_12',
#  'Reg_XShifts_13',
#  'Reg_XShifts_14',
#  'Reg_XShifts_15',
#  'Reg_XShifts_16',
#  'Reg_YShifts_ 1',
#  'Reg_YShifts_ 2',
#  'Reg_YShifts_ 3',
#  'Reg_YShifts_ 4',
#  'Reg_YShifts_ 5',
#  'Reg_YShifts_ 6',
#  'Reg_YShifts_ 7',
#  'Reg_YShifts_ 8',
#  'Reg_YShifts_ 9',
#  'Reg_YShifts_10',
#  'Reg_YShifts_11',
#  'Reg_YShifts_12',
#  'Reg_YShifts_13',
#  'Reg_YShifts_14',
#  'Reg_YShifts_15',
#  'Reg_YShifts_16',
#  'Reg_InGroupXShifts_ 1',
#  'Reg_InGroupXShifts_ 2',
#  'Reg_InGroupXShifts_ 3',
#  'Reg_InGroupXShifts_ 4',
#  'Reg_InGroupXShifts_ 5',
#  'Reg_InGroupXShifts_ 6',
#  'Reg_InGroupXShifts_ 7',
#  'Reg_InGroupXShifts_ 8',
#  'Reg_InGroupXShifts_ 9',
#  'Reg_InGroupXShifts_10',
#  'Reg_InGroupXShifts_11',
#  'Reg_InGroupXShifts_12',
#  'Reg_InGroupXShifts_13',
#  'Reg_InGroupXShifts_14',
#  'Reg_InGroupXShifts_15',
#  'Reg_InGroupXShifts_16',
#  'Reg_InGroupYShifts_ 1',
#  'Reg_InGroupYShifts_ 2',
#  'Reg_InGroupYShifts_ 3',
#  'Reg_InGroupYShifts_ 4',
#  'Reg_InGroupYShifts_ 5',
#  'Reg_InGroupYShifts_ 6',
#  'Reg_InGroupYShifts_ 7',
#  'Reg_InGroupYShifts_ 8',
#  'Reg_InGroupYShifts_ 9',
#  'Reg_InGroupYShifts_10',
#  'Reg_InGroupYShifts_11',
#  'Reg_InGroupYShifts_12',
#  'Reg_InGroupYShifts_13',
#  'Reg_InGroupYShifts_14',
#  'Reg_InGroupYShifts_15',
#  'Reg_InGroupYShifts_16',
#  'Reg_GroupXShifts_1',
#  'Reg_GroupXShifts_2',
#  'Reg_GroupXShifts_3',
#  'Reg_GroupXShifts_4',
#  'Reg_GroupYShifts_1',
#  'Reg_GroupYShifts_2',
#  'Reg_GroupYShifts_3',
#  'Reg_GroupYShifts_4',
#  'Reg_ShiftSumSquares',
#  'Reg_InGroupShiftMeanSumSquares',
#  'Reg_GroupShiftSumSquares',
#  'Reg_InGroupPeakIntensity_1_1',
#  'Reg_InGroupPeakIntensity_1_2',
#  'Reg_InGroupPeakIntensity_1_3',
#  'Reg_InGroupPeakIntensity_2_1',
#  'Reg_InGroupPeakIntensity_2_2',
#  'Reg_InGroupPeakIntensity_2_3',
#  'Reg_InGroupPeakIntensity_3_1',
#  'Reg_InGroupPeakIntensity_3_2',
#  'Reg_InGroupPeakIntensity_3_3',
#  'Reg_InGroupPeakIntensity_4_1',
#  'Reg_InGroupPeakIntensity_4_2',
#  'Reg_InGroupPeakIntensity_4_3',
#  'Reg_InGroupPeakIntensitySum_1',
#  'Reg_InGroupPeakIntensitySum_2',
#  'Reg_InGroupPeakIntensitySum_3',
#  'Reg_InGroupPeakIntensitySum_4',
#  'Reg_InGroupErrorSum_1',
#  'Reg_InGroupErrorSum_2',
#  'Reg_InGroupErrorSum_3',
#  'Reg_InGroupErrorSum_4',
#  'Reg_GroupPeakIntensity_1',
#  'Reg_GroupPeakIntensity_2',
#  'Reg_GroupPeakIntensity_3',
#  'Reg_GroupPeakIntensitySum',
#  'Reg_GroupErrorSum',
#  'Reg_Date',
#  'Reg_Checked',
#  'Reg_Quality',
#  'Reg_FailureReason',
#  'Reg_ShiftAmount',
#  'Reg_ShiftType',
#  'Reg_ClassifiedBy',
#  'Reg_Notes',
#  'Reg_RegCheckedDate',
#  'Seg_Method',
#  'Seg_ThresholdMethod',
#  'Seg_ThreshNumberOfSigmasFromMean',
#  'Seg_NumberOfGaussiansFit',
#  'Seg_BackgroundGaussianMean',
#  'Seg_BackgroundGaussianStd',
#  'Seg_BackgroundGaussianFitRSquared',
#  'Seg_GaussThreshold',
#  'Seg_BackgroundThreshold',
#  'Seg_DepositThreshold',
#  'Seg_MaskOpeningSize',
#  'Seg_ClosingShape',
#  'Seg_ClosingDiskRadius',
#  'Seg_DepositAreaMicrons2',
#  'Seg_LargestClusterArea',
#  'Seg_Eccentricity',
#  'Seg_MajorAxisMicrons',
#  'Seg_MinorAxisMicrons',
#  'Seg_Orientation',
#  'Seg_PerimeterMicrons',
#  'Seg_Date',
#  'Seg_Checked',
#  'Seg_ManualThreshold',
#  'Seg_Quality',
#  'Seg_FailureReason',
#  'Seg_UseMask',
#  'Seg_CalculateStats',
#  'Seg_UseArea',
#  'Seg_UseBlobAnalysis',
#  'Seg_ClassifiedBy',
#  'Seg_Notes',
#  'Seg_SegCheckedDate',
#  'Transmission_Background_Mean',
#  'Transmission_Background_Median',
#  'Transmission_Background_Std',
#  'Transmission_Background_MAD',
#  'Transmission_Background_Mode',
#  'Transmission_Deposit_Mean',
#  'Transmission_Deposit_Median',
#  'Transmission_Deposit_Std',
#  'Transmission_Deposit_MAD',
#  'Transmission_Deposit_Mode',
#  'Transmission_Full_Mean',
#  'Transmission_Full_Std',
#  'Transmission_Mean_Contrast',
#  'Transmission_Median_Contrast',
#  'Transmission_Mode_Contrast',
#  'Depolarization_Index_Background_Mean',
#  'Depolarization_Index_Background_Median',
#  'Depolarization_Index_Background_Std',
#  'Depolarization_Index_Background_MAD',
#  'Depolarization_Index_Background_Mode',
#  'Depolarization_Index_Deposit_Mean',
#  'Depolarization_Index_Deposit_Median',
#  'Depolarization_Index_Deposit_Std',
#  'Depolarization_Index_Deposit_MAD',
#  'Depolarization_Index_Deposit_Mode',
#  'Depolarization_Index_Full_Mean',
#  'Depolarization_Index_Full_Std',
#  'Depolarization_Index_Mean_Contrast',
#  'Depolarization_Index_Median_Contrast',
#  'Depolarization_Index_Mode_Contrast',
#  'Q_metric_Background_Mean',
#  'Q_metric_Background_Median',
#  'Q_metric_Background_Std',
#  'Q_metric_Background_MAD',
#  'Q_metric_Background_Mode',
#  'Q_metric_Deposit_Mean',
#  'Q_metric_Deposit_Median',
#  'Q_metric_Deposit_Std',
#  'Q_metric_Deposit_MAD',
#  'Q_metric_Deposit_Mode',
#  'Q_metric_Full_Mean',
#  'Q_metric_Full_Std',
#  'Q_metric_Mean_Contrast',
#  'Q_metric_Median_Contrast',
#  'Q_metric_Mode_Contrast',
#  'Anisotropy_Lin_Background_Mean',
#  'Anisotropy_Lin_Background_Median',
#  'Anisotropy_Lin_Background_Std',
#  'Anisotropy_Lin_Background_MAD',
#  'Anisotropy_Lin_Background_Mode',
#  'Anisotropy_Lin_Deposit_Mean',
#  'Anisotropy_Lin_Deposit_Median',
#  'Anisotropy_Lin_Deposit_Std',
#  'Anisotropy_Lin_Deposit_MAD',
#  'Anisotropy_Lin_Deposit_Mode',
#  'Anisotropy_Lin_Full_Mean',
#  'Anisotropy_Lin_Full_Std',
#  'Anisotropy_Lin_Mean_Contrast',
#  'Anisotropy_Lin_Median_Contrast',
#  'Anisotropy_Lin_Mode_Contrast',
#  'Anisotropy_Circ_Background_Mean',
#  'Anisotropy_Circ_Background_Median',
#  'Anisotropy_Circ_Background_Std',
#  'Anisotropy_Circ_Background_MAD',
#  'Anisotropy_Circ_Background_Mode',
#  'Anisotropy_Circ_Deposit_Mean',
#  'Anisotropy_Circ_Deposit_Median',
#  'Anisotropy_Circ_Deposit_Std',
#  'Anisotropy_Circ_Deposit_MAD',
#  'Anisotropy_Circ_Deposit_Mode',
#  'Anisotropy_Circ_Full_Mean',
#  'Anisotropy_Circ_Full_Std',
#  'Anisotropy_Circ_Mean_Contrast',
#  'Anisotropy_Circ_Median_Contrast',
#  'Anisotropy_Circ_Mode_Contrast',
#  'Anisotropy_Theta_Background_CircMean',
#  'Anisotropy_Theta_Background_CircStd',
#  'Anisotropy_Theta_Background_Mode',
#  'Anisotropy_Theta_Deposit_CircMean',
#  'Anisotropy_Theta_Deposit_CircStd',
#  'Anisotropy_Theta_Deposit_Mode',
#  'Anisotropy_Theta_Full_Mean',
#  'Anisotropy_Theta_Full_Std',
#  'Anisotropy_Theta_Mean_Contrast',
#  'Anisotropy_Theta_Median_Contrast',
#  'Anisotropy_Theta_Mode_Contrast',
#  'Anisotropy_Theta_CircMean_Contrast',
#  'Anisotropy_Total_Background_Mean',
#  'Anisotropy_Total_Background_Median',
#  'Anisotropy_Total_Background_Std',
#  'Anisotropy_Total_Background_MAD',
#  'Anisotropy_Total_Background_Mode',
#  'Anisotropy_Total_Deposit_Mean',
#  'Anisotropy_Total_Deposit_Median',
#  'Anisotropy_Total_Deposit_Std',
#  'Anisotropy_Total_Deposit_MAD',
#  'Anisotropy_Total_Deposit_Mode',
#  'Anisotropy_Total_Full_Mean',
#  'Anisotropy_Total_Full_Std',
#  'Anisotropy_Total_Mean_Contrast',
#  'Anisotropy_Total_Median_Contrast',
#  'Anisotropy_Total_Mode_Contrast',
#  'Polarizance_Lin_Background_Mean',
#  'Polarizance_Lin_Background_Median',
#  'Polarizance_Lin_Background_Std',
#  'Polarizance_Lin_Background_MAD',
#  'Polarizance_Lin_Background_Mode',
#  'Polarizance_Lin_Deposit_Mean',
#  'Polarizance_Lin_Deposit_Median',
#  'Polarizance_Lin_Deposit_Std',
#  'Polarizance_Lin_Deposit_MAD',
#  'Polarizance_Lin_Deposit_Mode',
#  'Polarizance_Lin_Full_Mean',
#  'Polarizance_Lin_Full_Std',
#  'Polarizance_Lin_Mean_Contrast',
#  'Polarizance_Lin_Median_Contrast',
#  'Polarizance_Lin_Mode_Contrast',
#  'Polarizance_Circ_Background_AbsMean',
#  'Polarizance_Circ_Background_AbsMedian',
#  'Polarizance_Circ_Background_Mean',
#  'Polarizance_Circ_Background_Median',
#  'Polarizance_Circ_Background_Std',
#  'Polarizance_Circ_Background_MAD',
#  'Polarizance_Circ_Background_Mode',
#  'Polarizance_Circ_Deposit_AbsMean',
#  'Polarizance_Circ_Deposit_AbsMedian',
#  'Polarizance_Circ_Deposit_Mean',
#  'Polarizance_Circ_Deposit_Median',
#  'Polarizance_Circ_Deposit_Std',
#  'Polarizance_Circ_Deposit_MAD',
#  'Polarizance_Circ_Deposit_Mode',
#  'Polarizance_Circ_Full_Mean',
#  'Polarizance_Circ_Full_Std',
#  'Polarizance_Circ_AbsMean_Contrast',
#  'Polarizance_Circ_AbsMedian_Contrast',
#  'Polarizance_Circ_Mean_Contrast',
#  'Polarizance_Circ_Median_Contrast',
#  'Polarizance_Circ_Mode_Contrast',
#  'Polarizance_Theta_Background_CircMean',
#  'Polarizance_Theta_Background_CircStd',
#  'Polarizance_Theta_Background_Mode',
#  'Polarizance_Theta_Deposit_CircMean',
#  'Polarizance_Theta_Deposit_CircStd',
#  'Polarizance_Theta_Deposit_Mode',
#  'Polarizance_Theta_Full_Mean',
#  'Polarizance_Theta_Full_Std',
#  'Polarizance_Theta_Mean_Contrast',
#  'Polarizance_Theta_Median_Contrast',
#  'Polarizance_Theta_Mode_Contrast',
#  'Polarizance_Theta_CircMean_Contrast',
#  'Polarizance_Total_Background_Mean',
#  'Polarizance_Total_Background_Median',
#  'Polarizance_Total_Background_Std',
#  'Polarizance_Total_Background_MAD',
#  'Polarizance_Total_Background_Mode',
#  'Polarizance_Total_Deposit_Mean',
#  'Polarizance_Total_Deposit_Median',
#  'Polarizance_Total_Deposit_Std',
#  'Polarizance_Total_Deposit_MAD',
#  'Polarizance_Total_Deposit_Mode',
#  'Polarizance_Total_Full_Mean',
#  'Polarizance_Total_Full_Std',
#  'Polarizance_Total_Mean_Contrast',
#  'Polarizance_Total_Median_Contrast',
#  'Polarizance_Total_Mode_Contrast',
#  'Diattenuation_Lin_Background_Mean',
#  'Diattenuation_Lin_Background_Median',
#  'Diattenuation_Lin_Background_Std',
#  'Diattenuation_Lin_Background_MAD',
#  'Diattenuation_Lin_Background_Mode',
#  'Diattenuation_Lin_Deposit_Mean',
#  'Diattenuation_Lin_Deposit_Median',
#  'Diattenuation_Lin_Deposit_Std',
#  'Diattenuation_Lin_Deposit_MAD',
#  'Diattenuation_Lin_Deposit_Mode',
#  'Diattenuation_Lin_Full_Mean',
#  'Diattenuation_Lin_Full_Std',
#  'Diattenuation_Lin_Mean_Contrast',
#  'Diattenuation_Lin_Median_Contrast',
#  'Diattenuation_Lin_Mode_Contrast',
#  'Diattenuation_Circ_Background_AbsMean',
#  'Diattenuation_Circ_Background_AbsMedian',
#  'Diattenuation_Circ_Background_Mean',
#  'Diattenuation_Circ_Background_Median',
#  'Diattenuation_Circ_Background_Std',
#  'Diattenuation_Circ_Background_MAD',
#  'Diattenuation_Circ_Background_Mode',
#  'Diattenuation_Circ_Deposit_AbsMean',
#  'Diattenuation_Circ_Deposit_AbsMedian',
#  'Diattenuation_Circ_Deposit_Mean',
#  'Diattenuation_Circ_Deposit_Median',
#  'Diattenuation_Circ_Deposit_Std',
#  'Diattenuation_Circ_Deposit_MAD',
#  'Diattenuation_Circ_Deposit_Mode',
#  'Diattenuation_Circ_Full_Mean',
#  'Diattenuation_Circ_Full_Std',
#  'Diattenuation_Circ_AbsMean_Contrast',
#  'Diattenuation_Circ_AbsMedian_Contrast',
#  'Diattenuation_Circ_Mean_Contrast',
#  'Diattenuation_Circ_Median_Contrast',
#  'Diattenuation_Circ_Mode_Contrast',
#  'Diattenuation_Theta_Background_CircMean',
#  'Diattenuation_Theta_Background_CircStd',
#  'Diattenuation_Theta_Background_Mode',
#  'Diattenuation_Theta_Deposit_CircMean',
#  'Diattenuation_Theta_Deposit_CircStd',
#  'Diattenuation_Theta_Deposit_Mode',
#  'Diattenuation_Theta_Full_Mean',
#  'Diattenuation_Theta_Full_Std',
#  'Diattenuation_Theta_Mean_Contrast',
#  'Diattenuation_Theta_Median_Contrast',
#  'Diattenuation_Theta_Mode_Contrast',
#  'Diattenuation_Theta_CircMean_Contrast',
#  'Diattenuation_Total_Background_Mean',
#  'Diattenuation_Total_Background_Median',
#  'Diattenuation_Total_Background_Std',
#  'Diattenuation_Total_Background_MAD',
#  'Diattenuation_Total_Background_Mode',
#  'Diattenuation_Total_Deposit_Mean',
#  'Diattenuation_Total_Deposit_Median',
#  'Diattenuation_Total_Deposit_Std',
#  'Diattenuation_Total_Deposit_MAD',
#  'Diattenuation_Total_Deposit_Mode',
#  'Diattenuation_Total_Full_Mean',
#  'Diattenuation_Total_Full_Std',
#  'Diattenuation_Total_Mean_Contrast',
#  'Diattenuation_Total_Median_Contrast',
#  'Diattenuation_Total_Mode_Contrast',
#  'Depolarization_Power_Background_Mean',
#  'Depolarization_Power_Background_Median',
#  'Depolarization_Power_Background_Std',
#  'Depolarization_Power_Background_MAD',
#  'Depolarization_Power_Background_Mode',
#  'Depolarization_Power_Deposit_Mean',
#  'Depolarization_Power_Deposit_Median',
#  'Depolarization_Power_Deposit_Std',
#  'Depolarization_Power_Deposit_MAD',
#  'Depolarization_Power_Deposit_Mode',
#  'Depolarization_Power_Full_Mean',
#  'Depolarization_Power_Full_Std',
#  'Depolarization_Power_Mean_Contrast',
#  'Depolarization_Power_Median_Contrast',
#  'Depolarization_Power_Mode_Contrast',
#  'Retardance_Lin_Background_Mean',
#  'Retardance_Lin_Background_Median',
#  'Retardance_Lin_Background_Std',
#  'Retardance_Lin_Background_MAD',
#  'Retardance_Lin_Background_Mode',
#  'Retardance_Lin_Deposit_Mean',
#  'Retardance_Lin_Deposit_Median',
#  'Retardance_Lin_Deposit_Std',
#  'Retardance_Lin_Deposit_MAD',
#  'Retardance_Lin_Deposit_Mode',
#  'Retardance_Lin_Full_Mean',
#  'Retardance_Lin_Full_Std',
#  'Retardance_Lin_Mean_Contrast',
#  'Retardance_Lin_Median_Contrast',
#  'Retardance_Lin_Mode_Contrast',
#  'Retardance_Circ_Background_AbsMean',
#  'Retardance_Circ_Background_AbsMedian',
#  'Retardance_Circ_Background_Mean',
#  'Retardance_Circ_Background_Median',
#  'Retardance_Circ_Background_Std',
#  'Retardance_Circ_Background_MAD',
#  'Retardance_Circ_Background_Mode',
#  'Retardance_Circ_Deposit_AbsMean',
#  'Retardance_Circ_Deposit_AbsMedian',
#  'Retardance_Circ_Deposit_Mean',
#  'Retardance_Circ_Deposit_Median',
#  'Retardance_Circ_Deposit_Std',
#  'Retardance_Circ_Deposit_MAD',
#  'Retardance_Circ_Deposit_Mode',
#  'Retardance_Circ_Full_Mean',
#  'Retardance_Circ_Full_Std',
#  'Retardance_Circ_AbsMean_Contrast',
#  'Retardance_Circ_AbsMedian_Contrast',
#  'Retardance_Circ_Mean_Contrast',
#  'Retardance_Circ_Median_Contrast',
#  'Retardance_Circ_Mode_Contrast',
#  'Retardance_Theta_Background_CircMean',
#  'Retardance_Theta_Background_CircStd',
#  'Retardance_Theta_Background_Mode',
#  'Retardance_Theta_Deposit_CircMean',
#  'Retardance_Theta_Deposit_CircStd',
#  'Retardance_Theta_Deposit_Mode',
#  'Retardance_Theta_Full_Mean',
#  'Retardance_Theta_Full_Std',
#  'Retardance_Theta_Mean_Contrast',
#  'Retardance_Theta_Median_Contrast',
#  'Retardance_Theta_Mode_Contrast',
#  'Retardance_Theta_CircMean_Contrast',
#  'Retardance_Total_Background_Mean',
#  'Retardance_Total_Background_Median',
#  'Retardance_Total_Background_Std',
#  'Retardance_Total_Background_MAD',
#  'Retardance_Total_Background_Mode',
#  'Retardance_Total_Deposit_Mean',
#  'Retardance_Total_Deposit_Median',
#  'Retardance_Total_Deposit_Std',
#  'Retardance_Total_Deposit_MAD',
#  'Retardance_Total_Deposit_Mode',
#  'Retardance_Total_Full_Mean',
#  'Retardance_Total_Full_Std',
#  'Retardance_Total_Mean_Contrast',
#  'Retardance_Total_Median_Contrast',
#  'Retardance_Total_Mode_Contrast',
#  't_metric_Background_Mean',
#  't_metric_Background_Median',
#  't_metric_Background_Std',
#  't_metric_Background_MAD',
#  't_metric_Background_Mode',
#  't_metric_Deposit_Mean',
#  't_metric_Deposit_Median',
#  't_metric_Deposit_Std',
#  't_metric_Deposit_MAD',
#  't_metric_Deposit_Mode',
#  't_metric_Full_Mean',
#  't_metric_Full_Std',
#  't_metric_Mean_Contrast',
#  't_metric_Median_Contrast',
#  't_metric_Mode_Contrast',
#  'b_metric_Background_Mean',
#  'b_metric_Background_Median',
#  'b_metric_Background_Std',
#  'b_metric_Background_MAD',
#  'b_metric_Background_Mode',
#  'b_metric_Deposit_Mean',
#  'b_metric_Deposit_Median',
#  'b_metric_Deposit_Std',
#  'b_metric_Deposit_MAD',
#  'b_metric_Deposit_Mode',
#  'b_metric_Full_Mean',
#  'b_metric_Full_Std',
#  'b_metric_Mean_Contrast',
#  'b_metric_Median_Contrast',
#  'b_metric_Mode_Contrast',
#  'x_metric_Background_Mean',
#  'x_metric_Background_Median',
#  'x_metric_Background_Std',
#  'x_metric_Background_MAD',
#  'x_metric_Background_Mode',
#  'x_metric_Deposit_Mean',
#  'x_metric_Deposit_Median',
#  'x_metric_Deposit_Std',
#  'x_metric_Deposit_MAD',
#  'x_metric_Deposit_Mode',
#  'x_metric_Full_Mean',
#  'x_metric_Full_Std',
#  'x_metric_Mean_Contrast',
#  'x_metric_Median_Contrast',
#  'x_metric_Mode_Contrast',
#  'A_metric_Background_Mean',
#  'A_metric_Background_Median',
#  'A_metric_Background_Std',
#  'A_metric_Background_MAD',
#  'A_metric_Background_Mode',
#  'A_metric_Deposit_Mean',
#  'A_metric_Deposit_Median',
#  'A_metric_Deposit_Std',
#  'A_metric_Deposit_MAD',
#  'A_metric_Deposit_Mode',
#  'A_metric_Full_Mean',
#  'A_metric_Full_Std',
#  'A_metric_Mean_Contrast',
#  'A_metric_Median_Contrast',
#  'A_metric_Mode_Contrast',
#  'MM11_Background_Mean',
#  'MM11_Background_Median',
#  'MM11_Background_Std',
#  'MM11_Background_MAD',
#  'MM11_Background_Mode',
#  'MM11_Deposit_Mean',
#  'MM11_Deposit_Median',
#  'MM11_Deposit_Std',
#  'MM11_Deposit_MAD',
#  'MM11_Deposit_Mode',
#  'MM11_Full_Mean',
#  'MM11_Full_Std',
#  'MM11_Mean_Contrast',
#  'MM11_Median_Contrast',
#  'MM11_Mode_Contrast',
#  'MM12_Background_Mean',
#  'MM12_Background_Median',
#  'MM12_Background_Std',
#  'MM12_Background_MAD',
#  'MM12_Background_Mode',
#  'MM12_Deposit_Mean',
#  'MM12_Deposit_Median',
#  'MM12_Deposit_Std',
#  'MM12_Deposit_MAD',
#  'MM12_Deposit_Mode',
#  'MM12_Full_Mean',
#  'MM12_Full_Std',
#  'MM12_Mean_Contrast',
#  'MM12_Median_Contrast',
#  'MM12_Mode_Contrast',
#  'MM13_Background_Mean',
#  'MM13_Background_Median',
#  'MM13_Background_Std',
#  'MM13_Background_MAD',
#  'MM13_Background_Mode',
#  'MM13_Deposit_Mean',
#  'MM13_Deposit_Median',
#  'MM13_Deposit_Std',
#  'MM13_Deposit_MAD',
#  'MM13_Deposit_Mode',
#  'MM13_Full_Mean',
#  'MM13_Full_Std',
#  'MM13_Mean_Contrast',
#  'MM13_Median_Contrast',
#  'MM13_Mode_Contrast',
#  'MM14_Background_Mean',
#  'MM14_Background_Median',
#  'MM14_Background_Std',
#  'MM14_Background_MAD',
#  'MM14_Background_Mode',
#  'MM14_Deposit_Mean',
#  'MM14_Deposit_Median',
#  'MM14_Deposit_Std',
#  'MM14_Deposit_MAD',
#  'MM14_Deposit_Mode',
#  'MM14_Full_Mean',
#  'MM14_Full_Std',
#  'MM14_Mean_Contrast',
#  'MM14_Median_Contrast',
#  'MM14_Mode_Contrast',
#  'MM21_Background_Mean',
#  'MM21_Background_Median',
#  'MM21_Background_Std',
#  'MM21_Background_MAD',
#  'MM21_Background_Mode',
#  'MM21_Deposit_Mean',
#  'MM21_Deposit_Median',
#  'MM21_Deposit_Std',
#  'MM21_Deposit_MAD',
#  'MM21_Deposit_Mode',
#  'MM21_Full_Mean',
#  'MM21_Full_Std',
#  'MM21_Mean_Contrast',
#  'MM21_Median_Contrast',
#  'MM21_Mode_Contrast',
#  'MM22_Background_Mean',
#  'MM22_Background_Median',
#  'MM22_Background_Std',
#  'MM22_Background_MAD',
#  'MM22_Background_Mode',
#  'MM22_Deposit_Mean',
#  'MM22_Deposit_Median',
#  'MM22_Deposit_Std',
#  'MM22_Deposit_MAD',
#  'MM22_Deposit_Mode',
#  'MM22_Full_Mean',
#  'MM22_Full_Std',
#  'MM22_Mean_Contrast',
#  'MM22_Median_Contrast',
#  'MM22_Mode_Contrast',
#  'MM23_Background_Mean',
#  'MM23_Background_Median',
#  'MM23_Background_Std',
#  'MM23_Background_MAD',
#  'MM23_Background_Mode',
#  'MM23_Deposit_Mean',
#  'MM23_Deposit_Median',
#  'MM23_Deposit_Std',
#  'MM23_Deposit_MAD',
#  'MM23_Deposit_Mode',
#  'MM23_Full_Mean',
#  'MM23_Full_Std',
#  'MM23_Mean_Contrast',
#  'MM23_Median_Contrast',
#  'MM23_Mode_Contrast',
#  'MM24_Background_Mean',
#  'MM24_Background_Median',
#  'MM24_Background_Std',
#  'MM24_Background_MAD',
#  'MM24_Background_Mode',
#  'MM24_Deposit_Mean',
#  'MM24_Deposit_Median',
#  'MM24_Deposit_Std',
#  'MM24_Deposit_MAD',
#  'MM24_Deposit_Mode',
#  'MM24_Full_Mean',
#  'MM24_Full_Std',
#  'MM24_Mean_Contrast',
#  'MM24_Median_Contrast',
#  'MM24_Mode_Contrast',
#  'MM31_Background_Mean',
#  'MM31_Background_Median',
#  'MM31_Background_Std',
#  'MM31_Background_MAD',
#  'MM31_Background_Mode',
#  'MM31_Deposit_Mean',
#  'MM31_Deposit_Median',
#  'MM31_Deposit_Std',
#  'MM31_Deposit_MAD',
#  'MM31_Deposit_Mode',
#  'MM31_Full_Mean',
#  'MM31_Full_Std',
#  'MM31_Mean_Contrast',
#  'MM31_Median_Contrast',
#  'MM31_Mode_Contrast',
#  'MM32_Background_Mean',
#  'MM32_Background_Median',
#  'MM32_Background_Std',
#  'MM32_Background_MAD',
#  'MM32_Background_Mode',
#  'MM32_Deposit_Mean',
#  'MM32_Deposit_Median',
#  'MM32_Deposit_Std',
#  'MM32_Deposit_MAD',
#  'MM32_Deposit_Mode',
#  'MM32_Full_Mean',
#  'MM32_Full_Std',
#  'MM32_Mean_Contrast',
#  'MM32_Median_Contrast',
#  'MM32_Mode_Contrast',
#  'MM33_Background_Mean',
#  'MM33_Background_Median',
#  'MM33_Background_Std',
#  'MM33_Background_MAD',
#  'MM33_Background_Mode',
#  'MM33_Deposit_Mean',
#  'MM33_Deposit_Median',
#  'MM33_Deposit_Std',
#  'MM33_Deposit_MAD',
#  'MM33_Deposit_Mode',
#  'MM33_Full_Mean',
#  'MM33_Full_Std',
#  'MM33_Mean_Contrast',
#  'MM33_Median_Contrast',
#  'MM33_Mode_Contrast',
#  'MM34_Background_Mean',
#  'MM34_Background_Median',
#  'MM34_Background_Std',
#  'MM34_Background_MAD',
#  'MM34_Background_Mode',
#  'MM34_Deposit_Mean',
#  'MM34_Deposit_Median',
#  'MM34_Deposit_Std',
#  'MM34_Deposit_MAD',
#  'MM34_Deposit_Mode',
#  'MM34_Full_Mean',
#  'MM34_Full_Std',
#  'MM34_Mean_Contrast',
#  'MM34_Median_Contrast',
#  'MM34_Mode_Contrast',
#  'MM41_Background_Mean',
#  'MM41_Background_Median',
#  'MM41_Background_Std',
#  'MM41_Background_MAD',
#  'MM41_Background_Mode',
#  'MM41_Deposit_Mean',
#  'MM41_Deposit_Median',
#  'MM41_Deposit_Std',
#  'MM41_Deposit_MAD',
#  'MM41_Deposit_Mode',
#  'MM41_Full_Mean',
#  'MM41_Full_Std',
#  'MM41_Mean_Contrast',
#  'MM41_Median_Contrast',
#  'MM41_Mode_Contrast',
#  'MM42_Background_Mean',
#  'MM42_Background_Median',
#  'MM42_Background_Std',
#  'MM42_Background_MAD',
#  'MM42_Background_Mode',
#  'MM42_Deposit_Mean',
#  'MM42_Deposit_Median',
#  'MM42_Deposit_Std',
#  'MM42_Deposit_MAD',
#  'MM42_Deposit_Mode',
#  'MM42_Full_Mean',
#  'MM42_Full_Std',
#  'MM42_Mean_Contrast',
#  'MM42_Median_Contrast',
#  'MM42_Mode_Contrast',
#  'MM43_Background_Mean',
#  'MM43_Background_Median',
#  'MM43_Background_Std',
#  'MM43_Background_MAD',
#  'MM43_Background_Mode',
#  'MM43_Deposit_Mean',
#  'MM43_Deposit_Median',
#  'MM43_Deposit_Std',
#  'MM43_Deposit_MAD',
#  'MM43_Deposit_Mode',
#  'MM43_Full_Mean',
#  'MM43_Full_Std',
#  'MM43_Mean_Contrast',
#  'MM43_Median_Contrast',
#  'MM43_Mode_Contrast',
#  'MM44_Background_Mean',
#  'MM44_Background_Median',
#  'MM44_Background_Std',
#  'MM44_Background_MAD',
#  'MM44_Background_Mode',
#  'MM44_Deposit_Mean',
#  'MM44_Deposit_Median',
#  'MM44_Deposit_Std',
#  'MM44_Deposit_MAD',
#  'MM44_Deposit_Mode',
#  'MM44_Full_Mean',
#  'MM44_Full_Std',
#  'MM44_Mean_Contrast',
#  'MM44_Median_Contrast',
#  'MM44_Mode_Contrast']

# %%
# Adjust some values in the table
# The Q metric
df[["Q_metric_Background_Mean", "Q_metric_Background_Std", "Q_metric_Deposit_Mean", "Q_metric_Deposit_Std", 
    "Q_metric_Full_Mean", "Q_metric_Full_Std"]] = \
df[["Q_metric_Background_Mean", "Q_metric_Background_Std", "Q_metric_Deposit_Mean", "Q_metric_Deposit_Std", 
    "Q_metric_Full_Mean", "Q_metric_Full_Std"]].divide(3) 
# The Linear retardance
df[["Retardance_Lin_Background_Mean","Retardance_Lin_Background_Std", 
    "Retardance_Lin_Deposit_Mean", "Retardance_Lin_Deposit_Std", 
    "Retardance_Lin_Full_Mean", "Retardance_Lin_Full_Std"]] = \
df[["Retardance_Lin_Background_Mean","Retardance_Lin_Background_Std", 
    "Retardance_Lin_Deposit_Mean", "Retardance_Lin_Deposit_Std", 
    "Retardance_Lin_Full_Mean", "Retardance_Lin_Full_Std"]].divide(180)

# %%
df_label = df[["RegionFolder", "Subject" ,  "FluoroSignal", "CrossedSignal"]]
df_label.set_index(["RegionFolder", "Subject"], inplace=True)
# Statistics of the number 
print("  Number of each class \n"
      "  Fluo_T_Cross_T: " + str(sum(np.multiply(df_label["FluoroSignal"], df_label["CrossedSignal"]))) + "\n" + 
      "  Fluo_T_Cross_F: " + str(sum(np.multiply(df_label["FluoroSignal"] == 1, df_label["CrossedSignal"] == 0))) + "\n"+
      "  Fluo_F_Cross_T: " + str(sum(np.multiply(df_label["FluoroSignal"] == 0, df_label["CrossedSignal"] == 1))) + "\n"+
      "  Fluo_F_Cross_F: " + str(sum(np.multiply(df_label["FluoroSignal"] == 0, df_label["CrossedSignal"] == 0))) + "\n"
     )
# it's better to separate the class and fine tune the training examples
# Out:
#   Number of each class
#   Fluo_T_Cross_T: 789
#   Fluo_T_Cross_F: 20
#   Fluo_F_Cross_T: 131
#   Fluo_F_Cross_F: 7

# %%
# df for background
dfb = df[["RegionFolder", "Subject",
          "Depolarization_Power_Background_Mean", "Depolarization_Power_Background_Std", 
          "Q_metric_Background_Mean", "Q_metric_Background_Std",
          "Anisotropy_Lin_Background_Mean", "Anisotropy_Lin_Background_Std",
          "Polarizance_Lin_Background_Mean", "Polarizance_Lin_Background_Std",
          "Diattenuation_Lin_Background_Mean", "Diattenuation_Lin_Background_Std",
          "Retardance_Lin_Background_Mean", "Retardance_Lin_Background_Std", 
          "FluoroSignal", "CrossedSignal"
        ]]
dfb.set_index(["RegionFolder", "Subject"], inplace=True)
# df for deposits
dfd = df[["RegionFolder", "Subject", 
          "Depolarization_Power_Deposit_Mean", "Depolarization_Power_Deposit_Std", 
          "Q_metric_Deposit_Mean", "Q_metric_Deposit_Std",
          "Anisotropy_Lin_Deposit_Mean", "Anisotropy_Lin_Deposit_Std",
          "Polarizance_Lin_Deposit_Mean", "Polarizance_Lin_Deposit_Std",
          "Diattenuation_Lin_Deposit_Mean", "Diattenuation_Lin_Deposit_Std",
          "Retardance_Lin_Deposit_Mean", "Retardance_Lin_Deposit_Std",
          "FluoroSignal", "CrossedSignal"
        ]]
dfd.set_index(["RegionFolder", "Subject"], inplace=True)
# df for full stats
dff =  df[["RegionFolder", "Subject", 
          "Depolarization_Power_Full_Mean", "Depolarization_Power_Full_Std", 
          "Q_metric_Full_Mean", "Q_metric_Full_Std",
          "Anisotropy_Lin_Full_Mean", "Anisotropy_Lin_Full_Std",
          "Polarizance_Lin_Full_Mean", "Polarizance_Lin_Full_Std",
          "Diattenuation_Lin_Full_Mean", "Diattenuation_Lin_Full_Std",
          "Retardance_Lin_Full_Mean", "Retardance_Lin_Full_Std",
          "FluoroSignal", "CrossedSignal"
        ]]
dff.set_index(["RegionFolder", "Subject"], inplace=True)

# %% [markdown]
# ## Data Preparation (Ignore)
# <a id="dataprepi"></a>

# %% [markdown]
# make the data matrix reasonable:
# 1. downsize the number of fluo-cross positive data points down to similar level as the rest
# 2. The number of no fluo no cross is too small (maybe use some background ?)
# 3. Replace the deposit average of Cross_F by full average

# %%
df_ftct = dfd.loc[(dfd["FluoroSignal"]==1) & (dfd["CrossedSignal"] == 1)]
df_ftcf = dfd.loc[(dfd["FluoroSignal"]==1) & (dfd["CrossedSignal"] == 0)]
df_ffct = dfd.loc[(dfd["FluoroSignal"]==0) & (dfd["CrossedSignal"] == 1)]
df_ffcf = dfd.loc[(dfd["FluoroSignal"]==0) & (dfd["CrossedSignal"] == 0)]

# %%
# Use K-means clustering to extract 100 representative points from the 789 ftct data points
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=100, max_iter=3000).fit(df_ftct.iloc[:, 0:12].values)
ftct_c = kmeans.cluster_centers_

# %%
# Replace the statistiscs of fpcf and ffcf deposits with their full average
dff_ftcf = dff.loc[(dff["FluoroSignal"]==1) & (dff["CrossedSignal"] == 0)]
dff_ffcf = dff.loc[(dff["FluoroSignal"]==0) & (dff["CrossedSignal"] == 0)]
df_ftcf.iloc[:, 0:12] = dff_ftcf.iloc[:, 0:12].values
df_ffcf.iloc[:, 0:12] = dff_ffcf.iloc[:, 0:12].values
# Out:
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Create the data matrix
X = np.concatenate((ftct_c, df_ftcf.iloc[:, 0:12].values, 
                    df_ffct.iloc[:, 0:12].values, df_ffcf.iloc[:, 0:12].values),
                    axis=0)
y_full = np.concatenate((np.tile([1,1], (ftct_c.shape[0], 1)), 
                         df_ftcf.iloc[:, 12:14].values,
                         df_ffct.iloc[:, 12:14].values, 
                         df_ffcf.iloc[:, 12:14].values), 
                         axis=0)

# %% [markdown]
# ## Data Preparation (Balancing) (Ignore)
# <a id="dataprepb"></a>

# %%
# Replace the statistiscs of fpcf and ffcf deposits with their full average
# dff_ftcf = dff.loc[(dff["FluoroSignal"]==1) & (dff["CrossedSignal"] == 0)]
# dff_ffcf = dff.loc[(dff["FluoroSignal"]==0) & (dff["CrossedSignal"] == 0)]
# df_ftcf.iloc[:, 0:12] = dff_ftcf.iloc[:, 0:12].values
# df_ffcf.iloc[:, 0:12] = dff_ffcf.iloc[:, 0:12].values

dfd.loc[(dff["FluoroSignal"]==1) & (dff["CrossedSignal"] == 0)] = dff.loc[(dff["FluoroSignal"]==1) & (dff["CrossedSignal"] == 0)].values.copy()
dfd.loc[(dff["FluoroSignal"]==0) & (dff["CrossedSignal"] == 0)] = dff.loc[(dff["FluoroSignal"]==0) & (dff["CrossedSignal"] == 0)].values.copy()
# Out:
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Adding an equal number of background averages to the data set as ffcf (fluorescence false crossed false)
# Extracting background of ftct data 
dfb_ffcf = dfb[(dfd["FluoroSignal"]==1) & (dfd["CrossedSignal"]==1)]
# change the name of columns
oldname = ["Depolarization_Power_Background_Mean", "Depolarization_Power_Background_Std", 
           "Q_metric_Background_Mean", "Q_metric_Background_Std",
           "Anisotropy_Lin_Background_Mean", "Anisotropy_Lin_Background_Std",
           "Polarizance_Lin_Background_Mean", "Polarizance_Lin_Background_Std",
           "Diattenuation_Lin_Background_Mean", "Diattenuation_Lin_Background_Std",
           "Retardance_Lin_Background_Mean", "Retardance_Lin_Background_Std", 
           "FluoroSignal", "CrossedSignal"]
newname = ["Depolarization_Power_Deposit_Mean", "Depolarization_Power_Deposit_Std", 
           "Q_metric_Deposit_Mean", "Q_metric_Deposit_Std",
           "Anisotropy_Lin_Deposit_Mean", "Anisotropy_Lin_Deposit_Std",
           "Polarizance_Lin_Deposit_Mean", "Polarizance_Lin_Deposit_Std",
           "Diattenuation_Lin_Deposit_Mean", "Diattenuation_Lin_Deposit_Std",
           "Retardance_Lin_Deposit_Mean", "Retardance_Lin_Deposit_Std",
           "FluoroSignal", "CrossedSignal"]
namedict = {oldname[i]: newname[i] for i in range(len(oldname))}
# Inpalce changing the names of the columns
dfb_ffcf.rename(columns = namedict, inplace=True)
dfb_ffcf["FluoroSignal"] = np.zeros(dfb_ffcf.shape[0], dtype=np.int32)
dfb_ffcf["CrossedSignal"] = np.zeros(dfb_ffcf.shape[0], dtype=np.int32)
dfd = pd.concat([dfd, dfb_ffcf])
# Out:
# D:\anaconda\lib\site-packages\pandas\core\frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Training Using Scikit Learn
# <a id="sklearn"></a>

# %%
# import basic fucntions
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import pipeline
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix 
from sklearn.model_selection import cross_val_score, RandomizedSearchCV, GridSearchCV
# Train support vector machine
from sklearn import svm
from scipy.stats import randint as sp_randint
from sklearn.ensemble import RandomForestClassifier

# %%
# select data_preparation scheme
def data_preparation_scheme(s_num):
    if s_num==1:
        # (ftct deposits), (ffct deposits + background(ffcf)) 
        dfct = dfd[dfd["CrossedSignal"]==1].copy()
        df_b = dfb.sample(frac=0.7, random_state=42).iloc[0:658, :]
        # change the name of columns
        oldname = ["Depolarization_Power_Background_Mean", "Depolarization_Power_Background_Std", 
                   "Q_metric_Background_Mean", "Q_metric_Background_Std",
                   "Anisotropy_Lin_Background_Mean", "Anisotropy_Lin_Background_Std",
                   "Polarizance_Lin_Background_Mean", "Polarizance_Lin_Background_Std",
                   "Diattenuation_Lin_Background_Mean", "Diattenuation_Lin_Background_Std",
                   "Retardance_Lin_Background_Mean", "Retardance_Lin_Background_Std", 
                   "FluoroSignal", "CrossedSignal"]
        newname = ["Depolarization_Power_Deposit_Mean", "Depolarization_Power_Deposit_Std", 
                   "Q_metric_Deposit_Mean", "Q_metric_Deposit_Std",
                   "Anisotropy_Lin_Deposit_Mean", "Anisotropy_Lin_Deposit_Std",
                   "Polarizance_Lin_Deposit_Mean", "Polarizance_Lin_Deposit_Std",
                   "Diattenuation_Lin_Deposit_Mean", "Diattenuation_Lin_Deposit_Std",
                   "Retardance_Lin_Deposit_Mean", "Retardance_Lin_Deposit_Std",
                   "FluoroSignal", "CrossedSignal"]
        namedict = {oldname[i]: newname[i] for i in range(len(oldname))}
        # Inpalce changing the names of the columns
        df_b.rename(columns = namedict, inplace=True)
        df_b["FluoroSignal"] = np.zeros(df_b.shape[0], dtype=np.int32)
        df_b["CrossedSignal"] = np.zeros(df_b.shape[0], dtype=np.int32)
        df_r = pd.concat([dfct, df_b])
        return(df_r)
    else:
        dfct_ft = dfd[(dfd["FluoroSignal"]==1) & (dfd["CrossedSignal"]==1)].copy()
        dfct_ff = dfd[(dfd["FluoroSignal"]==0) & (dfd["CrossedSignal"]==1)].copy()
        dfct_ft = dfct_ft.sample(frac=0.5, random_state=9)[0:3*dfct_ff.shape[0]]
        df_r = pd.concat([dfct_ft, dfct_ff])    
        return(df_r)

# %% [markdown]
# ### Support vector machine
# <a id="svm"></a>

# %%
def train_svm(data_train, label_train):
    wdict_svm = {0: 1, 1: 1}
    clf_svm = svm.SVC(class_weight=wdict_svm)
    # optimize the parameters
    param_dist = {"kernel": ["rbf", "poly"], 
                  "degree": [1, 2, 3],
                  "gamma": sp_randint(0, 10), 
                  "shrinking": [True, False]
                  }
    n_iter_search = 30
    rs_svm = RandomizedSearchCV(clf_svm, param_distributions=param_dist,
                                      n_iter=n_iter_search, cv=5)
    # train
    rs_svm.fit(data_train, label_train)
    return rs_svm

# %% [markdown]
# ### Ensemble learning (sklearn)
# <a id="ensemble"></a>

# %%
def train_rf(data_train, label_train):
    wdict_rf = {0: 1, 1: 1}
    clf_rf = RandomForestClassifier()
    param_dist = {"max_depth": [2, 3, 4, 5],
                  "n_estimators": [200, 500],
                  "bootstrap": [True, False],
                  "max_features": sp_randint(1, 12),
                  "min_samples_split": sp_randint(2, 11),
                  "criterion": ["gini", "entropy"]}
    n_iter_search = 30
    rs_rf = RandomizedSearchCV(clf_rf, param_distributions=param_dist,
                                      n_iter=n_iter_search, cv=5)
    # train
    rs_rf.fit(data_train, label_train)
    return rs_rf

# %% [markdown]
# ## Training using Xgboost
# <a id="xgboost"></a>

# %%
# import xgboost as xgb

# # # weight the classes
# # w = np.ones(y_train.shape[0])
# # w[y_train == 3] = 40
# # w[y_train == 4] = 6
# wt = 1
# # Use the scikit learn wrapper
# clf_xgb = xgb.XGBClassifier(max_depth=5, objective="binary:hinge", scale_pos_weight=wt, silent=1)
# # clf_xgb = xgb.XGBClassifier(max_depth=5, num_class=4, objective="multi:softmax")
# clf_xgb.fit(X_train, y_train)
# y_xgb_predict = clf_xgb.predict(X_test)
# df_temp = metric_scores(clf_xgb, "XGBoost", X_test, y_test, y_xgb_predict, X_train, y_train)

# df_sklearn_result = df_sklearn_result.append(df_temp)
# Out:
# D:\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# D:\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# D:\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# D:\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# D:\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# D:\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# D:\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# D:\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# D:\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# D:\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# D:\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %% [markdown]
# ## Training Using Tensorflow
# <a id="tf"></a>

# %%
# import tensorflow as tf
# Now there are only 12 features, nn won't produce better result

# %% [markdown]
# ## Summary of All Classifiers
# <a id="sklearn_sum"></a>

# %%
# function for preprocesing to genearte training and test data sets
def data_preprocessing(df_in):
    # Prepare the datamatrix and labels
    X_r = df_in.iloc[:, 0:(df_a.shape[1]-2)].values
    y = df_in["FluoroSignal"].values
    # Standarize X
    scaler = preprocessing.StandardScaler().fit(X_r)
    X = scaler.transform(X_r)
    X_train_, X_test_, y_train_, y_test_ = train_test_split(X, y, test_size=0.33, random_state=42) 
    return X_train_, X_test_, y_train_, y_test_, scaler

# Define a function for inputing stats from classifier to dataframe
def metric_scores(m_clf, mname, truevalt, predictvalt):
    # convert the multiclass label back to 2 class
    trueval = truevalt.copy()
    predictval = predictvalt.copy()
    accuracy = accuracy_score(trueval, predictval)
    precision = precision_score(trueval, predictval)
    # CV score of the best_estimator
    recall = recall_score(trueval, predictval)
    cvscore = m_clf.best_score_    
    df_scores = pd.DataFrame({"Method": mname, "Accuracy": [accuracy], "Precision": [precision], "Recall": [recall], 
                              "CV (mean)": [cvscore]})
    return df_scores

def train_models(X_train_in, X_test_in, y_train_in, y_test_in):  
    df_result = pd.DataFrame({"Method": [], "Accuracy": [], "Precision": [], "Recall": [], "CV (mean)": []})
    # svm
    rs_svm_t = train_svm(X_train_in, y_train_in)
    y_svm_predict = rs_svm_t.predict(X_test_in)
    df_temp1 = metric_scores(rs_svm_t, "SVM", y_test_in, y_svm_predict)
    df_result = df_result.append(df_temp1)
    # rf
    rs_rf_t = train_rf(X_train_in, y_train_in)
    y_rf_predict = rs_rf_t.predict(X_test_in)    
    df_temp2 = metric_scores(rs_rf_t, "RF", y_test_in, y_rf_predict)
    df_result = df_result.append(df_temp2)
    return df_result, rs_svm_t, y_svm_predict, rs_rf_t, y_rf_predict

# %%
# Scheme 1 (separate ftct deposit and (ffct deposits + ffcf background) for fluorescence)
df_1 = data_preparation_scheme(s_num=1)
X_train_1, X_test_1, y_train_1, y_test_1, scaler_data_1 = data_preprocessing(df_1)
df_result_1, rs_svm_model_1, y_svm_pred_val_1, rs_rf_model_1, y_rf_pred_val_1 = \
                                            train_models(X_train_1, X_test_1, y_train_1, y_test_1)

# Scheme 2 (separate ftct and ffct deposits for fluorescence)
df_2 = data_preparation_scheme(s_num=2)
X_train_2, X_test_2, y_train_2, y_test_2, scaler_data_2 = data_preprocessing(df_2)
df_result_2, rs_svm_model_2, y_svm_pred_val_2, rs_rf_model_2, y_rf_pred_val_2 = \
                                            train_models(X_train_2, X_test_2, y_train_2, y_test_2)

# %%
# Scheme 1 (separate ftct deposit and (ffct deposits + ffcf background) for fluorescence)
df_result_1.set_index(["Method"],  inplace=True)
df_result_1
# Out:
#         Accuracy  Precision    Recall  CV (mean)
# Method
# SVM     0.938580   0.928058  0.955556   0.912015
# RF      0.940499   0.925267  0.962963   0.929991

# %%
# Scheme 2 (separate ftct and ffct deposits for fluorescence)
df_result_2.set_index(["Method"],  inplace=True)
df_result_2
# Out:
#         Accuracy  Precision    Recall  CV (mean)
# Method
# SVM     0.809249   0.827586  0.937500   0.851852
# RF      0.832370   0.866667  0.914062   0.868946
